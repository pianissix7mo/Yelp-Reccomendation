# %% [markdown]
# # Problem Statement:  How can we recommend restauraunts to users, what are the best places to eat?
#
# ### Author: Mofei Wang, Matthew Blum
#
# We are going to build a recommender system to suggest the best restaurants and their offerings based on a user's location.  The goal of this notebook is to create a baseline model which can tell us some of the important features towards a recommended restaurant - ie, one which has 4 stars or better in the review.
#
# This notebook will go through:
#
# 1. Loading the data
# 2. Cleaning steps
# 3. EDA
# 4. Preparing the data for our baseline naive models
# 5. Running 3 different naive models
# 6. Discussing next steps

# %%
# !pip install eli5
# !pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: eli5 in c:\users\mofei\appdata\roaming\python\python39\site-packages (0.13.0)
# Requirement already satisfied: scikit-learn>=0.20 in c:\programdata\anaconda3\lib\site-packages (from eli5) (1.0.2)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\mofei\appdata\roaming\python\python39\site-packages (from eli5) (3.1.2)
# Requirement already satisfied: numpy>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from eli5) (1.21.5)
# Requirement already satisfied: attrs>17.1.0 in c:\programdata\anaconda3\lib\site-packages (from eli5) (21.4.0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\programdata\anaconda3\lib\site-packages (from eli5) (0.8.9)
# Requirement already satisfied: graphviz in c:\users\mofei\appdata\roaming\python\python39\site-packages (from eli5) (0.20.1)
# Requirement already satisfied: scipy in c:\users\mofei\appdata\roaming\python\python39\site-packages (from eli5) (1.10.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from eli5) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=3.0.0->eli5) (2.0.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.20->eli5) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.20->eli5) (2.2.0)
# WARNING: You are using pip version 21.3.1; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in c:\users\mofei\appdata\roaming\python\python39\site-packages (0.12.2)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\mofei\appdata\roaming\python\python39\site-packages (from geopandas) (3.5.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: fiona>=1.8 in c:\users\mofei\appdata\roaming\python\python39\site-packages (from geopandas) (1.9.3)
# Requirement already satisfied: pandas>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: shapely>=1.7 in c:\users\mofei\appdata\roaming\python\python39\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (4.11.3)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\mofei\appdata\roaming\python\python39\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: munch>=2.3.2 in c:\users\mofei\appdata\roaming\python\python39\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: click~=8.0 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\mofei\appdata\roaming\python\python39\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->geopandas) (3.0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8->geopandas) (0.4.4)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata->fiona>=1.8->geopandas) (3.7.0)
# WARNING: You are using pip version 21.3.1; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import sklearn

import matplotlib.pyplot as plt
import json
import geopandas as gpd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, Conv1D, MaxPooling1D, Flatten, SimpleRNN, LSTM, Dropout, Bidirectional

from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
import eli5
from eli5.sklearn import PermutationImportance

# %% [markdown]
# # Load Datasets From Json Files
#
# The datasets are stored as json files.  They are:
#
# 1. User - includes user data such as # of reviews left, average stars, etc
# 2. Business - includes business info such as location, category, etc
# 3. review - includes review info, such as user who left it, star rating, etc
# 4. checkin - includes checkins and time made by users
# 5. tip - includes tips about the place, such as "check out the secret menu item"

# %%
user_df = []

with open("data/yelp_academic_dataset_user.json") as f:
    reader = pd.read_json(f, orient="records", lines=True, chunksize=1000)
        
    for chunk in reader:
        reduced_chunk = chunk.drop(columns=['name'])
        user_df.append(reduced_chunk)
    
user_df  = pd.concat(user_df , ignore_index=True)

# %%
business_json_path = 'data/yelp_academic_dataset_business.json'
business_df = pd.read_json(business_json_path, lines=True)
business_json_path = 'data/yelp_academic_dataset_checkin.json'
checkin_df = pd.read_json(business_json_path, lines=True)
business_json_path = 'data/yelp_academic_dataset_tip.json'
tip_df = pd.read_json(business_json_path, lines=True)

# %%
review_df = []
r_dtypes = {"stars": np.float16, 
            "useful": np.int32, 
            "funny": np.int32,
            "cool": np.int32,
           }
with open("data/yelp_academic_dataset_review.json", "r") as f:
    reader = pd.read_json(f, orient="records", lines=True, 
                          dtype=r_dtypes, chunksize=1000)
        
    for chunk in reader:
        reduced_chunk = chunk.drop(columns=['review_id'])
        review_df.append(reduced_chunk)
    
review_df  = pd.concat(review_df , ignore_index=True)

# %%
business_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150346 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  float64
#  7   longitude     150346 non-null  float64
#  8   stars         150346 non-null  float64
#  9   review_count  150346 non-null  int64
#  10  is_open       150346 non-null  int64
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 16.1+ MB

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987897 entries, 0 to 1987896
# Data columns (total 21 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   user_id             object
#  1   review_count        int64
#  2   yelping_since       object
#  3   useful              int64
#  4   funny               int64
#  5   cool                int64
#  6   elite               object
#  7   friends             object
#  8   fans                int64
#  9   average_stars       float64
#  10  compliment_hot      int64
#  11  compliment_more     int64
#  12  compliment_profile  int64
#  13  compliment_cute     int64
#  14  compliment_list     int64
#  15  compliment_note     int64
#  16  compliment_plain    int64
#  17  compliment_cool     int64
#  18  compliment_funny    int64
#  19  compliment_writer   int64
#  20  compliment_photos   int64
# dtypes: float64(1), int64(16), object(4)
# memory usage: 318.5+ MB

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user_id      object
#  1   business_id  object
#  2   stars        float16
#  3   useful       int32
#  4   funny        int32
#  5   cool         int32
#  6   text         object
#  7   date         datetime64[ns]
# dtypes: datetime64[ns](1), float16(1), int32(3), object(3)
# memory usage: 306.7+ MB

# %%
checkin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131930 entries, 0 to 131929
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   business_id  131930 non-null  object
#  1   date         131930 non-null  object
# dtypes: object(2)
# memory usage: 2.0+ MB

# %%
tip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908915 entries, 0 to 908914
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           908915 non-null  object
#  1   business_id       908915 non-null  object
#  2   text              908915 non-null  object
#  3   date              908915 non-null  datetime64[ns]
#  4   compliment_count  908915 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 34.7+ MB

# %% [markdown]
# # Number of reviews over different time

# %%
plot = sns.histplot(review_df["date"].dropna())
plot.set_title("Number of reviews vs Years")
# Out:
# Text(0.5, 1.0, 'Number of reviews vs Years')

# %% [markdown]
# # Data Cleaning

# %%
#only keep opening businesses with Restaurant or Food in their categories
#remove some unecessary columns
business_df = business_df.loc[business_df['is_open'] == 1]
business_new= business_df.assign(categories = business_df.categories
                         .str.split(', ')).explode('categories')
business_clean = business_new[business_new.categories.str.contains('Restaurant|Food',
                      case=False,na=False)]
business_clean = business_clean.loc[business_clean['state'] == "FL"]
business_clean = business_clean.groupby('business_id').agg({
    'name': 'first',
    'address': 'first',
    'city': 'first',
    'state': 'first',
    'postal_code': 'first',
    'latitude': 'first',
    'longitude': 'first',
    'stars': 'first',
    'review_count': 'first',
    'is_open': 'first',
    'attributes': 'first',
    'hours':'first',
    'categories': lambda x: ','.join(x)
}).reset_index()

business_clean.drop(['address', 'city', 'state', 'is_open'], axis=1, inplace=True)

#remove the reviews before 2012
review_clean = review_df.loc[review_df["date"].dt.year >= 2012]

#remove the users with an average of 1 star or 5 stars
user_clean = user_df[(user_df["average_stars"] > 1 ) & (user_df["average_stars"]  < 5)]

# %%
business_new.categories.value_counts()
# Out:
# Restaurants               34987
# Food                      20419
# Shopping                  20186
# Home Services             13322
# Beauty & Spas             12263
#                           ...
# Guamanian                     1
# Cheese Tasting Classes        1
# Bike Repair                   1
# Tonkatsu                      1
# Trade Fairs                   1
# Name: categories, Length: 1302, dtype: int64

# %%
# keep all three major datasets updated
review_clean = review_clean.loc[review_clean['business_id'].isin(business_clean["business_id"])]
user_clean = user_df.loc[user_df['user_id'].isin(review_clean["user_id"])]
business_clean = business_clean.loc[business_clean["business_id"].isin(review_clean["business_id"])]

# %% [markdown]
# # Check the sum/percentage of nans

# %%
business_clean.isna().sum()
# Out:
# business_id       0
# name              0
# postal_code       0
# latitude          0
# longitude         0
# stars             0
# review_count      0
# attributes      123
# hours           663
# categories        0
# dtype: int64

# %%
user_clean.isna().sum()
# Out:
# user_id               0
# review_count          0
# yelping_since         0
# useful                0
# funny                 0
# cool                  0
# elite                 0
# friends               0
# fans                  0
# average_stars         0
# compliment_hot        0
# compliment_more       0
# compliment_profile    0
# compliment_cute       0
# compliment_list       0
# compliment_note       0
# compliment_plain      0
# compliment_cool       0
# compliment_funny      0
# compliment_writer     0
# compliment_photos     0
# dtype: int64

# %%
review_clean.isna().sum()
# Out:
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %%
business_clean.notnull().mean().sub(1).mul(-1).replace(0, np.nan).dropna().sort_values().plot.bar()
# Out:
# <AxesSubplot:>

# %%
business_clean.head()
# Out:
#               business_id                          name postal_code  \
# 0  ---kPU91CF4Lq2-WlRu9Lw             Frankie's Raw Bar       34652
# 1  --SJXpAa0E-GCp2smaHf0A                    Winn Dixie       33579
# 2  --rS-rnOIZxoiDA8yctWpQ       Publix GreenWise Market       33602
# 3  -0EdehHjIQc0DtYU8QcAig  New Tung Tung Two Restaurant       34638
# 4  -1oygVebK81K8JEPI6H6Lw             Bruegger's Bagels       33602
#
#     latitude  longitude  stars  review_count  \
# 0  28.217288 -82.733344    4.5            24
# 1  27.791333 -82.332240    2.5            13
# 2  27.943291 -82.450160    5.0             8
# 3  28.260154 -82.474816    3.0            35
# 4  27.947732 -82.455849    4.0            72
#
#                                           attributes  \
# 0  {'Alcohol': 'u'none'', 'OutdoorSeating': 'True...
# 1  {'BikeParking': 'False', 'RestaurantsPriceRang...
# 2  {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 3  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 4  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
#
#                                                hours  \
# 0  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 1  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...
# 2  {'Monday': '7:0-22:0', 'Tuesday': '7:0-22:0', ...
# 3                                               None
# 4  {'Monday': '6:30-12:0', 'Tuesday': '6:30-12:0'...
#
#                              categories
# 0  Seafood,Restaurants,Food,Food Trucks
# 1                                  Food
# 2                                  Food
# 3                           Restaurants
# 4                      Restaurants,Food

# %%
review_clean.head()
# Out:
#                     user_id             business_id  stars  useful  funny  \
# 15   1C2lxzUo1Hyye4RFIXly3g  BVndHaLihEYbr76Z0CMEGw    5.0       0      0
# 84   _jaJDV-qTBafatbObmtzpA  cg4JFJcCxRTTMmcg9O9KtA    1.0       0      1
# 94   4ubLHlnMFFw4JikcXr-F4w  f4PA-f1tcN1bIpZJLdFsQQ    5.0       3      0
# 98   3TL6HZ1JrKcNTvGDWKlrow  GyC36Pn0Q1-qHnqXys6yFg    1.0       0      0
# 109  JriXL8qqw_tJ1mpwtlBabg  1QVB0_-piu0GXes87BXeGw    5.0       1      0
#
#      cool                                               text  \
# 15      0  Great place for breakfast! I had the waffle, w...
# 84      0  Skip this train wreck if you are looking for d...
# 94      0  I must admit, I wasn't expecting much. This pl...
# 98      0  Service and management terrible... After messi...
# 109     0  Love this place...best hot dogs and chili dogs...
#
#                    date
# 15  2014-10-11 16:22:06
# 84  2018-02-11 03:11:20
# 94  2017-05-26 02:32:01
# 98  2013-12-07 13:17:13
# 109 2017-10-11 01:27:15

# %%
user_clean.head()
# Out:
#                    user_id  review_count        yelping_since  useful  funny  \
# 22  FT9CFS39sjZxVjCTrDHmdg           201  2010-06-14 21:44:28     555    141
# 32  NIhcRW6DWvk1JQhDhXwgOQ          2288  2005-12-30 13:47:19   12773   4199
# 36  rppTTi-kfF8-qyiArNemag           460  2006-01-24 14:33:32     700    149
# 56  RgDVC3ZUBqpEe6Y1kPhIpw          1282  2009-02-23 14:08:31   12640  10005
# 69  q7iWal_rXNSHkHeCMMvZxQ           500  2011-06-01 21:02:59    2546   1433
#
#      cool                                              elite  \
# 22    203                                          2015,2016
# 32   7971  2006,2007,2008,2009,2010,2011,2012,2013,2014,2...
# 36    425            2010,2012,2013,2014,2015,2016,2017,2018
# 56  11149            2009,2010,2011,2012,2013,2014,2015,2016
# 69   1862  2011,2012,2013,2014,2015,2016,2017,2018,2019,2...
#
#                                               friends  fans  average_stars  \
# 22  ElaFwOTdEpkiYPkHMpOwXQ, nbnftigv3fj8oS6k-waLYQ...     5           3.52
# 32  T1upaPMzuW7pNj74fO1rjA, CP28puvAEimt4ziuGTDaHA...   345           3.69
# 36  HzoQKKHDq9BI37dyJAAtGA, Inh7WS8hpmiUmNDhtLK-ZQ...    49           3.33
# 56  sHozd2pcOKwHtPr8VlZJfg, 7mL9cvICl8fuCQTM89a-SA...   804           4.17
# 69  PVv_Y9_I59V_RUD-Wh8PxQ, c8vifRL3PmMZ2-aUf1A3pA...   104           3.95
#
#     ...  compliment_more  compliment_profile  compliment_cute  \
# 22  ...                0                   0                0
# 32  ...               63                  46               47
# 36  ...               11                   2                2
# 56  ...              102                 108              138
# 69  ...               25                   2               15
#
#     compliment_list  compliment_note  compliment_plain  compliment_cool  \
# 22                0               11                 8               21
# 32               21              518               773              867
# 36                0               16                23               43
# 56               65              898              2584             1731
# 69                7              187               339              325
#
#     compliment_funny  compliment_writer  compliment_photos
# 22                21                 12                  0
# 32               867                310                231
# 36                43                 20                 25
# 56              1731                551                177
# 69               325                143                 77
#
# [5 rows x 21 columns]

# %% [markdown]
# # Graphs to show some properties of the datasets

# %%
sns.set(rc={'figure.figsize':(11.7,4)})
plot = sns.histplot(np.log10(business_clean["review_count"]).dropna())
plot.set_xlabel("log10(review_count)")
plot.set_title("Distribution of log10(review_count) by business")
# Out:
# Text(0.5, 1.0, 'Distribution of log10(review_count) by business')

# %%
plot = sns.histplot(business_clean["stars"].dropna())
plot.set_xlabel("log10(review_count)")
plot.set_title("Distribution of stars by business")
# Out:
# Text(0.5, 1.0, 'Distribution of stars by business')

# %%
user_clean_map = user_clean.drop(['user_id', 'yelping_since', 'elite', 'friends'], axis=1)

ax = sns.heatmap(
    user_clean_map.corr() * 100,
    annot=True,
    cbar=False,
    fmt='.0f',
    # mask=np.triu()
)
ax.set_title("Features' heatmap")
# Out:
# Text(0.5, 1.0, "Features' heatmap")

# %%
pd.options.display.max_colwidth = 100

# %%
plot = sns.histplot(np.log10(user_clean["review_count"]).dropna())
plot.set_title("Distribution of log10(review_count) by user")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Text(0.5, 1.0, 'Distribution of log10(review_count) by user')

# %%
worldmap = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# Creating axes and plotting world map
fig, ax = plt.subplots(figsize=(12, 6))
worldmap.plot(color="lightgrey", ax=ax)

# Plotting our Impact Energy data with a color map
x = business_df['longitude']
y = business_df['latitude']
z = business_df['stars']
plt.scatter(x, y, s=20*z, c=z, alpha=0.6, vmin=0, vmax=5,
            cmap='autumn')
plt.colorbar(label='stars')

# Creating axis limits and title
plt.xlim([-180, 180])
plt.ylim([-90, 90])

plt.title("Business Locations Prior to Data cleaning")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
# Out:
# C:\Users\mofei\AppData\Local\Temp\ipykernel_8776\1045789567.py:13: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(label='stars')

# %% [markdown]
# # Create response variable and remove unnecessary variables
#
# We will be using "is_recommended" as a response variable, built where if a business has 4 stars or better, it is recommended, otherwise it is not.

# %%
baseline_dataset = business_clean.copy()
baseline_dataset["is_recommended"] = np.where(baseline_dataset['stars']>=4, 1, 0)
baseline_dataset = baseline_dataset.drop(['name','postal_code','hours','stars'], axis=1)

# %% [markdown]
# # One-hot encode categories

# %%
baseline_dataset_encoded = baseline_dataset['categories'].str.get_dummies(sep=',')

# Add the encoded categories to the original dataframe
baseline_dataset = pd.concat([baseline_dataset, baseline_dataset_encoded], axis=1)

# Drop the original categories column
baseline_dataset.drop("categories", axis=1, inplace=True)

# %% [markdown]
# # Drop null for attributes and one-hot encode it

# %%
baseline_dataset = baseline_dataset.dropna(subset=['attributes'])
baseline_dataset =baseline_dataset.reset_index(drop=True)

# %%
attribute_names = set()
for attributes in baseline_dataset['attributes']:
    attribute_names |= set(attributes.keys())

# create a dictionary to hold the one-hot encoded attributes
attribute_dict = {}
for attribute_name in attribute_names:
    attribute_dict[attribute_name] = []

# iterate over the attributes column and one-hot encode each attribute
for attributes in baseline_dataset['attributes']:
    for attribute_name in attribute_names:
        if attribute_name in attributes:
            attribute_dict[attribute_name].append(1 if attributes[attribute_name] == 'True' else 0)
        else:
            attribute_dict[attribute_name].append(0)

# create a dataframe from the attribute dictionary
attribute_baseline_dataset = pd.DataFrame(attribute_dict)

# concatenate the original dataframe with the attribute dataframe
baseline_dataset = pd.concat([baseline_dataset, attribute_baseline_dataset], axis=1)

# drop the original attributes column
baseline_dataset.drop('attributes', axis=1, inplace=True)

# %% [markdown]
# # merge some variables from review_dataframe
#
# Since we have a number of different datasets, we will merge them into one.  This join is on business id, where we compress it to unique business ids on the business table only.  The groupby does this aggregation.

# %%
useful_reviews = review_clean.groupby('business_id')['useful'].sum()
funny_reviews = review_clean.groupby('business_id')['funny'].sum()
cool_reviews = review_clean.groupby('business_id')['cool'].sum()

useful_reviews_df = pd.DataFrame({'business_id': useful_reviews.index, 'useful_reviews': useful_reviews.values})
funny_reviews_df = pd.DataFrame({'business_id': funny_reviews.index, 'funny_reviews': funny_reviews.values})
cool_reviews_df = pd.DataFrame({'business_id': cool_reviews.index, 'cool_reviews': cool_reviews.values})

# %%
useful_reviews_df = useful_reviews_df[useful_reviews_df.business_id.isin(baseline_dataset.business_id)]
funny_reviews_df = funny_reviews_df[funny_reviews_df.business_id.isin(baseline_dataset.business_id)]
cool_reviews_df = cool_reviews_df[cool_reviews_df.business_id.isin(baseline_dataset.business_id)]

# %%
baseline_dataset = pd.merge(baseline_dataset, useful_reviews_df, on='business_id', how='left')
baseline_dataset = pd.merge(baseline_dataset, funny_reviews_df, on='business_id', how='left')
baseline_dataset = pd.merge(baseline_dataset, cool_reviews_df, on='business_id', how='left')

# %%
baseline_dataset.drop('business_id', axis=1, inplace=True)

# %% [markdown]
# # Create train/test datasets

# %%
X = baseline_dataset.drop(['is_recommended'], axis=1)
y = baseline_dataset['is_recommended']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=109)

# %% [markdown]
# # Scale the x variables

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Create a naive model
#
# Our naive model is just a basic feed-forward neural network.

# %%
from sklearn.model_selection import GridSearchCV

# %%
epochs = 300
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(X_train.shape[1], ))) 
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu', kernel_regularizer='l2'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu', kernel_regularizer='l2'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu', kernel_regularizer='l2'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu', kernel_regularizer='l2'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu', kernel_regularizer='l2'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

learning_rate = 0.0001
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate, decay = 1e-6)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=optimizer)


history = model.fit(X_train_scaled, y_train, validation_split=0.2, epochs=epochs, batch_size=128)
# Out:
# Epoch 1/300
# 38/38 [==============================] - 2s 22ms/step - loss: 8.5638 - accuracy: 0.5156 - val_loss: 8.1705 - val_accuracy: 0.5742
# Epoch 2/300
# 38/38 [==============================] - 1s 16ms/step - loss: 7.8285 - accuracy: 0.5423 - val_loss: 7.4668 - val_accuracy: 0.6167
# Epoch 3/300
# 38/38 [==============================] - 1s 16ms/step - loss: 7.1555 - accuracy: 0.5717 - val_loss: 6.8219 - val_accuracy: 0.6408
# Epoch 4/300
# 38/38 [==============================] - 1s 17ms/step - loss: 6.5409 - accuracy: 0.5886 - val_loss: 6.2336 - val_accuracy: 0.6658
# Epoch 5/300
# 38/38 [==============================] - 1s 16ms/step - loss: 5.9768 - accuracy: 0.6314 - val_loss: 5.6977 - val_accuracy: 0.6825
# Epoch 6/300
# 38/38 [==============================] - 1s 16ms/step - loss: 5.4657 - accuracy: 0.6637 - val_loss: 5.2094 - val_accuracy: 0.7017
# Epoch 7/300
# 38/38 [==============================] - 1s 16ms/step - loss: 4.9991 - accuracy: 0.6881 - val_loss: 4.7653 - val_accuracy: 0.7167
# Epoch 8/300
# 38/38 [==============================] - 1s 16ms/step - loss: 4.5784 - accuracy: 0.7035 - val_loss: 4.3632 - val_accuracy: 0.7175
# Epoch 9/300
# 38/38 [==============================] - 1s 16ms/step - loss: 4.1929 - accuracy: 0.7148 - val_loss: 3.9980 - val_accuracy: 0.7242
# Epoch 10/300
# 38/38 [==============================] - 1s 17ms/step - loss: 3.8435 - accuracy: 0.7241 - val_loss: 3.6691 - val_accuracy: 0.7325
# Epoch 11/300
# 38/38 [==============================] - 1s 16ms/step - loss: 3.5289 - accuracy: 0.7271 - val_loss: 3.3733 - val_accuracy: 0.7217
# Epoch 12/300
# 38/38 [==============================] - 1s 16ms/step - loss: 3.2468 - accuracy: 0.7200 - val_loss: 3.1035 - val_accuracy: 0.7300
# Epoch 13/300
# 38/38 [==============================] - 1s 17ms/step - loss: 2.9943 - accuracy: 0.7289 - val_loss: 2.8670 - val_accuracy: 0.7275
# Epoch 14/300
# 38/38 [==============================] - 1s 16ms/step - loss: 2.7573 - accuracy: 0.7392 - val_loss: 2.6531 - val_accuracy: 0.7292
# Epoch 15/300
# 38/38 [==============================] - 1s 16ms/step - loss: 2.5578 - accuracy: 0.7327 - val_loss: 2.4608 - val_accuracy: 0.7292
# Epoch 16/300
# 38/38 [==============================] - 1s 16ms/step - loss: 2.3731 - accuracy: 0.7412 - val_loss: 2.2879 - val_accuracy: 0.7308
# Epoch 17/300
# 38/38 [==============================] - 1s 16ms/step - loss: 2.2034 - accuracy: 0.7383 - val_loss: 2.1331 - val_accuracy: 0.7275
# Epoch 18/300
# 38/38 [==============================] - 1s 16ms/step - loss: 2.0528 - accuracy: 0.7412 - val_loss: 1.9911 - val_accuracy: 0.7292
# Epoch 19/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.9160 - accuracy: 0.7467 - val_loss: 1.8630 - val_accuracy: 0.7325
# Epoch 20/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.7909 - accuracy: 0.7431 - val_loss: 1.7477 - val_accuracy: 0.7300
# Epoch 21/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.6824 - accuracy: 0.7515 - val_loss: 1.6421 - val_accuracy: 0.7325
# Epoch 22/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.5849 - accuracy: 0.7517 - val_loss: 1.5488 - val_accuracy: 0.7350
# Epoch 23/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.4910 - accuracy: 0.7487 - val_loss: 1.4674 - val_accuracy: 0.7342
# Epoch 24/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.4099 - accuracy: 0.7508 - val_loss: 1.3886 - val_accuracy: 0.7342
# Epoch 25/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.3324 - accuracy: 0.7548 - val_loss: 1.3202 - val_accuracy: 0.7317
# Epoch 26/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.2630 - accuracy: 0.7592 - val_loss: 1.2552 - val_accuracy: 0.7383
# Epoch 27/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.2041 - accuracy: 0.7573 - val_loss: 1.1979 - val_accuracy: 0.7392
# Epoch 28/300
# 38/38 [==============================] - 1s 17ms/step - loss: 1.1493 - accuracy: 0.7594 - val_loss: 1.1480 - val_accuracy: 0.7425
# Epoch 29/300
# 38/38 [==============================] - 1s 17ms/step - loss: 1.0996 - accuracy: 0.7558 - val_loss: 1.0991 - val_accuracy: 0.7450
# Epoch 30/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.0542 - accuracy: 0.7629 - val_loss: 1.0564 - val_accuracy: 0.7425
# Epoch 31/300
# 38/38 [==============================] - 1s 16ms/step - loss: 1.0157 - accuracy: 0.7581 - val_loss: 1.0217 - val_accuracy: 0.7317
# Epoch 32/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.9703 - accuracy: 0.7646 - val_loss: 0.9832 - val_accuracy: 0.7433
# Epoch 33/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.9418 - accuracy: 0.7581 - val_loss: 0.9518 - val_accuracy: 0.7475
# Epoch 34/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.9081 - accuracy: 0.7571 - val_loss: 0.9222 - val_accuracy: 0.7417
# Epoch 35/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.8757 - accuracy: 0.7736 - val_loss: 0.8964 - val_accuracy: 0.7425
# Epoch 36/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.8559 - accuracy: 0.7688 - val_loss: 0.8741 - val_accuracy: 0.7483
# Epoch 37/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0
300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4460 - accuracy: 0.8290 - val_loss: 0.6012 - val_accuracy: 0.7667
# Epoch 275/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4445 - accuracy: 0.8353 - val_loss: 0.6008 - val_accuracy: 0.7642
# Epoch 276/300
# 38/38 [==============================] - 1s 17ms/step - loss: 0.4465 - accuracy: 0.8353 - val_loss: 0.6015 - val_accuracy: 0.7567
# Epoch 277/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4447 - accuracy: 0.8355 - val_loss: 0.6012 - val_accuracy: 0.7625
# Epoch 278/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4382 - accuracy: 0.8388 - val_loss: 0.6014 - val_accuracy: 0.7600
# Epoch 279/300
# 38/38 [==============================] - 1s 17ms/step - loss: 0.4453 - accuracy: 0.8332 - val_loss: 0.6073 - val_accuracy: 0.7567
# Epoch 280/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4399 - accuracy: 0.8399 - val_loss: 0.6053 - val_accuracy: 0.7558
# Epoch 281/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4433 - accuracy: 0.8294 - val_loss: 0.6018 - val_accuracy: 0.7542
# Epoch 282/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4435 - accuracy: 0.8376 - val_loss: 0.6106 - val_accuracy: 0.7542
# Epoch 283/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4418 - accuracy: 0.8411 - val_loss: 0.6046 - val_accuracy: 0.7608
# Epoch 284/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4468 - accuracy: 0.8305 - val_loss: 0.6082 - val_accuracy: 0.7550
# Epoch 285/300
# 38/38 [==============================] - 1s 15ms/step - loss: 0.4510 - accuracy: 0.8324 - val_loss: 0.5979 - val_accuracy: 0.7608
# Epoch 286/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4436 - accuracy: 0.8367 - val_loss: 0.5999 - val_accuracy: 0.7592
# Epoch 287/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4456 - accuracy: 0.8338 - val_loss: 0.6007 - val_accuracy: 0.7583
# Epoch 288/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4449 - accuracy: 0.8386 - val_loss: 0.5983 - val_accuracy: 0.7617
# Epoch 289/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4412 - accuracy: 0.8365 - val_loss: 0.6002 - val_accuracy: 0.7658
# Epoch 290/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4440 - accuracy: 0.8394 - val_loss: 0.6030 - val_accuracy: 0.7575
# Epoch 291/300
# 38/38 [==============================] - 1s 15ms/step - loss: 0.4437 - accuracy: 0.8334 - val_loss: 0.6043 - val_accuracy: 0.7600
# Epoch 292/300
# 38/38 [==============================] - 1s 15ms/step - loss: 0.4396 - accuracy: 0.8384 - val_loss: 0.6057 - val_accuracy: 0.7533
# Epoch 293/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4408 - accuracy: 0.8407 - val_loss: 0.6055 - val_accuracy: 0.7575
# Epoch 294/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4425 - accuracy: 0.8378 - val_loss: 0.6088 - val_accuracy: 0.7575
# Epoch 295/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4472 - accuracy: 0.8319 - val_loss: 0.6012 - val_accuracy: 0.7575
# Epoch 296/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4386 - accuracy: 0.8407 - val_loss: 0.6038 - val_accuracy: 0.7633
# Epoch 297/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4416 - accuracy: 0.8359 - val_loss: 0.6057 - val_accuracy: 0.7550
# Epoch 298/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4361 - accuracy: 0.8451 - val_loss: 0.6024 - val_accuracy: 0.7583
# Epoch 299/300
# 38/38 [==============================] - 1s 17ms/step - loss: 0.4353 - accuracy: 0.8382 - val_loss: 0.6079 - val_accuracy: 0.7600
# Epoch 300/300
# 38/38 [==============================] - 1s 16ms/step - loss: 0.4408 - accuracy: 0.8394 - val_loss: 0.6049 - val_accuracy: 0.7592

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               33792
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 256)               65792
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 255,745
# Trainable params: 255,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.clf()
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.figure(figsize=(16,6))
plt.plot(range(1,epochs+1), train_acc, 'b', label='train accuracy',color="blue",marker='o', markersize=4)
plt.plot(range(1,epochs+1), val_acc, 'b', label='validation accuracy',color="red", marker='o', markersize=4)
plt.fill_between(range(1, epochs+1), np.array(val_acc)+2*np.std(val_acc), np.array(val_acc)-2*np.std(val_acc), color = 'purple', alpha = 0.2, label='+/- 2 Standard deviations')

plt.title('Naive model max(val accuracy) = ' + str(round(max(val_acc),3)),fontsize=20)
plt.xlabel('Epochs',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.grid(True)
plt.legend(loc = 'lower right',fontsize=16)

plt.show()
# Out:
# C:\Users\mofei\AppData\Local\Temp\ipykernel_8776\2453525352.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.2980392156862745, 0.4470588235294118, 0.6901960784313725, 1)). The keyword argument will take precedence.
#   plt.plot(range(1,epochs+1), train_acc, 'b', label='train accuracy',color="blue",marker='o', markersize=4)
# C:\Users\mofei\AppData\Local\Temp\ipykernel_8776\2453525352.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.2980392156862745, 0.4470588235294118, 0.6901960784313725, 1)). The keyword argument will take precedence.
#   plt.plot(range(1,epochs+1), val_acc, 'b', label='validation accuracy',color="red", marker='o', markersize=4)

# %%
n_trees_rf = 1000
tree_depth_rf = 60
train_scores_rf = []
cvmeans_rf = []
cvstds_rf = []

for depth in range(1, tree_depth_rf+1):
    rf = RandomForestClassifier(max_depth=depth,
                           n_estimators=n_trees_rf,
                           max_features= "sqrt",
                           random_state=109,
                           n_jobs=-1)
    rf.fit(X_train_scaled, y_train)
    train_score_rf = rf.score(X_train_scaled, y_train)
    train_scores_rf.append(train_score_rf)

    cv_results_rf = cross_val_score(rf, X_train_scaled, y_train, cv=5)
    cvmeans_rf.append(cv_results_rf.mean())
    cvstds_rf.append(cv_results_rf.std())

# %%
plt.figure(figsize=(20,9))
plt.grid(True, alpha=0.2)
plt.plot(range(1, tree_depth_rf+1), train_scores_rf, color='darkkhaki', lw=2, label="training scores", marker='o', markersize=4)
plt.plot(range(1, tree_depth_rf+1), cvmeans_rf, color='purple', lw=2, label="CV mean validation scores", marker='o', markersize=4)
plt.fill_between(range(1, tree_depth_rf+1), np.array(cvmeans_rf)+2*np.array(cvstds_rf), np.array(cvmeans_rf)-2*np.array(cvstds_rf), color = 'purple', alpha = 0.2, label='+/- 2 Standard deviations')
plt.xlabel('Maximum tree depth',fontsize=16)
plt.ylabel('Accuracy score',fontsize=16)
plt.xticks(list(range(1, tree_depth_rf+1, 5)), size=10)
plt.legend(fontsize=16)
plt.title(r'Accuracy scores vs maximum tree depths for Random Forest',fontsize=20);

# %%
best_cv_depth_rf = np.argmax(cvmeans_rf)+1
print(f'The highest mean CV accuracy score is {max(cvmeans_rf):.3f}.')
print(f'The best tree depth identified through CV is {best_cv_depth_rf}.')
# Out:
# The highest mean CV accuracy score is 0.765.
# The best tree depth identified through CV is 23.

# %%
rf_best = RandomForestClassifier(max_depth=best_cv_depth_rf,
                           n_estimators=n_trees_rf,
                           max_features=int(np.sqrt(X_train_scaled.shape[1])),
                           random_state=109, n_jobs=-1).fit(X_train_scaled, y_train)
best_cv_rf_train_score = rf_best.score(X_train_scaled, y_train)
best_cv_rf_test_score = rf_best.score(X_test_scaled, y_test)

# %%
print(
    "The random forest of depth-{} and {} trees achieves the "
    "following accuracy scores:\n\n\ttrain\t{:.4f}\n\tTEST\t{:.4f}"
    .format(
        best_cv_depth_rf,
        n_trees_rf,
        best_cv_rf_train_score,
        best_cv_rf_test_score,
    )
)
# Out:
# The random forest of depth-23 and 1000 trees achieves the following accuracy scores:
#
# 	train	0.9998
# 	TEST	0.7567

# %%
perm = PermutationImportance(rf_best, n_iter=10).fit(X_test_scaled, y_test)
eli5.show_weights(perm, feature_names=X_train.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1423
#
#                     &plusmn; 0.0232
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 cool_reviews
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0229
#
#                     &plusmn; 0.0099
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 funny_reviews
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0223
#
#                     &plusmn; 0.0124
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 WheelchairAccessible
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0130
#
#                     &plusmn; 0.0078
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Fast Food
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0111
#
#                     &plusmn; 0.0080
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 RestaurantsDelivery
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0074
#
#                     &plusmn; 0.0068
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DriveThru
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0063
#
#                     &plusmn; 0.0046
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HappyHour
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0050
#
#                     &plusmn; 0.0069
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Caters
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0042
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DogsAllowed
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0039
#
#                     &plusmn; 0.0036
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Specialty Food
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.56%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0033
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 RestaurantsTakeOut
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0029
#
#                     &plusmn; 0.0016
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Corkage
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0025
#
#                     &plusmn; 0.0072
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 RestaurantsGoodForGroups
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.83%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0025
#
#                     &plusmn; 0.0039
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BusinessAcceptsCreditCards
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0014
#
#                     &plusmn; 0.0059
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GoodForKids
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0010
#
#                     &plusmn; 0.0024
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BYOB
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0009
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GoodForDancing
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0008

# %% [markdown]
# # Display final results

# %%
y_pred = model.predict(X_test_scaled).round()
naive_score = accuracy_score(y_pred, y_test)
# y_pred1 = model1.predict(x_test_reshape).round()
# rnn_naive_score = accuracy_score(y_pred1, y_test)
# y_pred2 = model2.predict(x_test_reshape).round()
# cnn_naive_score = accuracy_score(y_pred2, y_test)
# Out:
# 47/47 [==============================] - 0s 6ms/step

# %%
naive_score
# Out:
# 0.7566666666666667

# %%
# naive_accuracy_scores =pd.DataFrame({'naive_model': [naive_score] ,
#         'rnn_naive_model': [rnn_naive_score],
#         'cnn_naive_model': [cnn_naive_score]})
# naive_accuracy_scores

# %% [markdown]
# # Baseline Model
#
# We experimented with a few different kinds of models, FFNN, RNN, and CNN.  Since our inputs are factors predicting if a restaurant is good or not, it makes sense the naive ffnn gives the best results, as CNN and RNN are better suited for different tasks.
#
# One consideration we had was performing sentiment analysis on review text - however, since all reviews must come with a star rating, and the star rating makes sense for an output of that task, it seemed like this would not provide much value.
#
#
# # Future Steps
#
# An approach we would like to try for the final model is a clustering method, where we take businesses from specific areas, find all the users who have rated them, and try to group those users by similarity - ie, if user A has reviewed restaurant 1, 2, and 3 with good reviews and restaurant 4 with a bad reveiw, and user B has reviewed restaurant 1, 2, and 4 the same, but has not reviewed restaurant 3, we will see the two users be considered "similar", and try to recommend restaurants based on that.
